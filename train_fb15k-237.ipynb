# %%
# !pip install -q -r requirements.txt

# %%
# !python -m utils.preprocess_data --dataset fb15k-237 --data_dir data/FB15k-237 --output_dir data-processed/fb15k-237

# %%
# !python -m utils.compute_context --data_dir data-processed/fb15k-237 --k 10 --seed 42

# %%
# !python train.py --config configs/fb15k-237.yaml

# %%
# !python evaluate.py --config configs/fb15k-237.yaml
