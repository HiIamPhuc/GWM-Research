# %%
# !pip install -q -r requirements.txt

# %%
# !python -m utils.preprocess_data --dataset wn18rr --data_dir data/WN18RR --output_dir data-processed/wn18rr

# %%
# !python -m utils.compute_context --data_dir data-processed/wn18rr --k 5 --seed 42

# %%
# !python train.py --config configs/wn18rr.yaml

# %%
# !python evaluate.py --config configs/wn18rr.yaml
